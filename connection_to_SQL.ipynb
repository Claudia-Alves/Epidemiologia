# %%
# !pip install --trusted-host pypi.org ipython-sql

# %%
import pandas as pd
import psycopg2
import matplotlib as plt

# %matplotlib inline

# %%
from sqlalchemy import create_engine

# Postgres username, password, and database name
POSTGRES_ADDRESS = 'localhost' ## INSERT YOUR DB ADDRESS IF IT'S NOT ON PANOPLY
POSTGRES_PORT = '5432'
POSTGRES_USERNAME = 'ClaudiaA' ## CHANGE THIS TO YOUR PANOPLY/POSTGRES USERNAME
POSTGRES_PASSWORD = '#iamadmin' ## CHANGE THIS TO YOUR PANOPLY/POSTGRES PASSWORD 
POSTGRES_DBNAME = 'Miebiom' ## CHANGE THIS TO YOUR DATABASE NAME
# A long string that contains the necessary Postgres login information
postgres_str = ('postgresql://{username}:{password}@{ipaddress}:{port}/{dbname}'.
                format(username=POSTGRES_USERNAME, password=POSTGRES_PASSWORD, 
                       ipaddress=POSTGRES_ADDRESS, port=POSTGRES_PORT, dbname=POSTGRES_DBNAME))
# Create the connection
cnx = create_engine(postgres_str)

# %%
query = pd.read_sql_query('''SELECT * FROM "portugal" LIMIT 10;''', cnx)
pd.read_sql_query('''SELECT * FROM "portugal" LIMIT 10;''', cnx)
# Out:
#    id                                               geom dicofre  \
# 0   1  0106000020B30E000001000000010300000001000000F1...  080506
# 1   2  0106000020B30E00000100000001030000000100000015...  081504
# 2   3  0106000020B30E00000100000001030000000100000052...  081504
# 3   4  0106000020B30E00000100000001030000000100000060...  080106
# 4   5  0106000020B30E0000010000000103000000010000009F...  080106
# 5   6  0106000020B30E00000100000001030000000100000034...  080106
# 6  95  0106000020B30E00000100000001030000000100000018...  080708
# 7   7  0106000020B30E00000100000001030000000100000035...  080106
# 8   8  0106000020B30E0000010000000103000000010000004C...  080106
# 9   9  0106000020B30E0000010000000103000000010000002E...  080106
#
#                    freguesia       concelho distrito              taa  \
# 0                 Montenegro           FARO     FARO   ÁREA PRINCIPAL
# 1                     Sagres  VILA DO BISPO     FARO  ÁREA SECUNDÁRIA
# ...

# %%
pd.read_sql_query('''SELECT "concelho" FROM "portugal" WHERE distrito='VIANA DO CASTELO';''', cnx)
# Out:
#               concelho
# 0               MONÇÃO
# 1    ARCOS DE VALDEVEZ
# 2    ARCOS DE VALDEVEZ
# 3              VALENÇA
# 4               MONÇÃO
# ..                 ...
# 204            MELGAÇO
# 205            MELGAÇO
# 206            MELGAÇO
# 207            MELGAÇO
# 208            MELGAÇO
#
# [209 rows x 1 columns]

# %%
pd.read_sql_query('''SELECT "concelho" FROM "portugal" WHERE freguesia='Lamas'  ;''', cnx)
# Out:
#                concelho
# 0      MIRANDA DO CORVO
# 1                 BRAGA
# 2  MACEDO DE CAVALEIROS
