# %%
import pandas as pd
import os as os

# %%
# %load_ext sql
# Out:
# The sql extension is already loaded. To reload it, use:
#   %reload_ext sql

# %%
user = os.getenv('ClaudiaA')
password = os.getenv('#iamadmin')
connection_string = "postgresql://ClaudiaA:#iamadmin@localhost/Miebiom".format(user=user, password=password)
# %sql $connection_string
# Out:
# 'Connected: ClaudiaA@Miebiom'

# %%
# %sql SELECT * FROM "confirmados_concelho" WHERE mais_recente IS NULL
# Out:
#  * postgresql://ClaudiaA:***@localhost/Miebiom
# 86 rows affected.
# [(9, 9, '0904', 'FIGUEIRA DE CASTELO RODRIGO', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, 3, None, 3, 3, 3, 3, 3, 3, 3, 3, None, None, None, None, None, None, None, None, None, None, None, None),
#  (31, 31, '1011', 'NAZARÉ', None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None, None),
# ...

# %%
# %sql select count(*) FROM "confirmados_concelho" WHERE mais_recente is NULL
# Out:
#  * postgresql://ClaudiaA:***@localhost/Miebiom
# 1 rows affected.
# [(86,)]

# %%
result = %sql SELECT concelho, mais_recente FROM confirmados_concelho WHERE mais_recente > 500
print(result)
# Out:
#  * postgresql://ClaudiaA:***@localhost/Miebiom
# 12 rows affected.
# +-------------------+--------------+
# |      concelho     | mais_recente |
# +-------------------+--------------+
# |        OVAR       |     574      |
# |       SINTRA      |     669      |
# |       PORTO       |     1266     |
# |     MATOSINHOS    |     1153     |
# |      GONDOMAR     |     1009     |
# | VILA NOVA DE GAIA |     1425     |
# |       BRAGA       |     1118     |
# |     GUIMARÃES     |     624      |
# |       LISBOA      |     1627     |
# |        MAIA       |     871      |
# |      COIMBRA      |     520      |
# |      VALONGO      |     729      |
# +-------------------+--------------+

# %%
# usando diretamente o resultado, em que type(result) = sql.run.ResultSet
# %matplotlib notebook
result.pie()
# Out:
# <img src="data:image/png;base64,..." width="640">
# ([<matplotlib.patches.Wedge at 0x211ca6ce208>,
# ...
#  [Text(1.0867010584472248, 0.17053096366842446, 'OVAR'),
#   Text(0.9691493847289372, 0.5203359204201865, 'SINTRA'),
#   Text(0.5780829733246261, 0.9358525930680321, 'PORTO'),
#   Text(-0.11270665211011253, 1.0942107706333961, 'MATOSINHOS'),
#   Text(-0.699279959101171, 0.8491216278010264, 'GONDOMAR'),
#   Text(-1.0730477226876738, 0.24200947261377428, 'VILA NOVA DE GAIA'),
#   Text(-0.9818279660884773, -0.49599782762282757, 'BRAGA'),
#   Text(-0.6486133368584945, -0.8884259897421334, 'GUIMARÃES'),
#   Text(-0.022221496619518763, -1.0997755248631371, 'LISBOA'),
#   Text(0.6719918094550137, -0.8708771486411713, 'MAIA'),
#   Text(0.9455154212728748, -0.5621392960247295, 'COIMBRA'),
#   Text(1.078575507343631, -0.21604368761532758, 'VALONGO')])

# %%
# usando pandas
df = result.DataFrame()    
df.plot.pie(y='mais_recente', labels=df['concelho'])
# Out:
# <img src="data:image/png;base64,..." width="640">
